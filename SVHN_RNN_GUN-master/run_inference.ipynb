# %%
from inference import Inference
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path_to_checkpoint_file = 'logs/train/model.ckpt-136000'
inference_model = Inference(path_to_checkpoint_file)
# Out:
# INFO:tensorflow:Restoring parameters from logs/train/model.ckpt-136000

# %%
path_to_image_file = './scratch_function/data/16.png'
image,inference_list = inference_model.run(path_to_image_file)
imshow(image)
inference_model.output(inference_list)
# Out:
# The candidate result as follow.
# No.	result	probability
#  1	 16	 0.606
#  2	 10	 0.285
#  3	 18	 0.067

# %%
path_to_image_file = './data/test/3291.png'
image,inference_list = inference_model.run(path_to_image_file)
imshow(image)
inference_model.output(inference_list)
# Out:
# The candidate result as follow.
# No.	result	probability
#  1	 111	 0.416
#  2	 113	 0.186
#  3	 115	 0.154

# %%
print(ord('A'))
print(chr(65))
# Out:
# 65
# A

# %%
print(inference_list)
# Out:
# [<digits_inference.Digits object at 0x000002BD7F325A90>, <digits_inference.Digits object at 0x000002BD7F325B00>, <digits_inference.Digits object at 0x000002BD7F325710>]
